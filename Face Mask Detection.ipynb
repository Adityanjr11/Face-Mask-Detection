# %%
import numpy as np
import keras
import keras.backend as k
from keras.layers import Conv2D,MaxPooling2D,SpatialDropout2D,Flatten,Dropout,Dense
from keras.models import Sequential,load_model
from keras.optimizers import Adam
from keras.preprocessing import image
import cv2
import datetime
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)))
model.add(MaxPooling2D() )
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D() )
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D() )
model.add(Flatten())
model.add(Dense(100,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
        '/content/drive/MyDrive/train',
        target_size=(150,150),
        batch_size=16 ,
        class_mode='binary')
# Out:
# Found 1131 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(
        '/content/drive/MyDrive/test',
        target_size=(150,150),
        batch_size=16,
        class_mode='binary')
# Out:
# Found 63 images belonging to 2 classes.

# %%
model_saved=model.fit_generator(
        training_set,
        epochs=10,
        validation_data=test_set,

        )
# Out:
# <ipython-input-12-a2a29289ba29>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_saved=model.fit_generator(
# Epoch 1/10
# 71/71 [==============================] - 178s 2s/step - loss: 0.4795 - accuracy: 0.7683 - val_loss: 0.1931 - val_accuracy: 0.9206
# Epoch 2/10
# 71/71 [==============================] - 47s 659ms/step - loss: 0.1407 - accuracy: 0.9461 - val_loss: 0.1398 - val_accuracy: 0.9524
# Epoch 3/10
# 71/71 [==============================] - 46s 640ms/step - loss: 0.1115 - accuracy: 0.9611 - val_loss: 0.1038 - val_accuracy: 0.9683
# Epoch 4/10
# 71/71 [==============================] - 46s 643ms/step - loss: 0.1334 - accuracy: 0.9576 - val_loss: 0.1624 - val_accuracy: 0.9365
# Epoch 5/10
# 71/71 [==============================] - 45s 636ms/step - loss: 0.1524 - accuracy: 0.9496 - val_loss: 0.2072 - val_accuracy: 0.9524
# Epoch 6/10
# 71/71 [==============================] - 45s 639ms/step - loss: 0.0843 - accuracy: 0.9699 - val_loss: 0.0771 - val_accuracy: 0.9683
# Epoch 7/10
# 71/71 [==============================] - 46s 641ms/step - loss: 0.0752 - accuracy: 0.9770 - val_loss: 0.1146 - val_accuracy: 0.9683
# Epoch 8/10
# 71/71 [==============================] - 45s 638ms/step - loss: 0.0901 - accuracy: 0.9699 - val_loss: 0.0934 - val_accuracy: 0.9683
# Epoch 9/10
# 71/71 [==============================] - 45s 628ms/step - loss: 0.0717 - accuracy: 0.9761 - val_loss: 0.0851 - val_accuracy: 0.9683
# Epoch 10/10
# 71/71 [==============================] - 45s 635ms/step - loss: 0.0566 - accuracy: 0.9814 - val_loss: 0.1049 - val_accuracy: 0.9683

# %%
model.save('FaceMask.h5',model_saved)

# %%
mymodel=load_model('FaceMask.h5')
#test_image=image.load_img('C:/Users/Karan/Desktop/ML Datasets/Face Mask Detection/Dataset/test/without_mask/30.jpg',target_size=(150,150,3))
test_image=load_img(r'/content/drive/MyDrive/test/with_mask/11-with-mask.jpg',
                          target_size=(150,150,3))
test_image
test_image=img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
mymodel.predict(test_image)[0][0]
# Out:
# 1/1 [==============================] - 0s 179ms/step
# 0.0

# %%
mymodel=load_model('FaceMask.h5')
#test_image=image.load_img('C:/Users/Karan/Desktop/ML Datasets/Face Mask Detection/Dataset/test/without_mask/30.jpg',target_size=(150,150,3))
test_image=load_img(r'/content/drive/MyDrive/test/with_mask/110-with-mask.jpg',
                          target_size=(150,150,3))
test_image
test_image=img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
mymodel.predict(test_image)[0][0]
# Out:
# 1/1 [==============================] - 0s 78ms/step
# 1.0
